# %% [markdown]
# I am going to implement naive bayes algoritm from scratch and use it make an email spam classifier for myself. So I will also be learning the transformer library here which is used for natural language processing i.e. text recognition and classification.

# %% [markdown]
# first of all we will import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing as pre
from sklearn.metrics import accuracy_score
import sklearn.model_selection as ms
from string import punctuation

# %% [markdown]
# now we will import the data i.e. some emails and their labels

# %%
df=pd.read_csv("d_naive_bayes_data2.csv")
df=df[1:]
# labelcoder=pre.LabelEncoder()
# df['spam']=labelcoder.fit_transform(df['spam'])
df.head()
# Out:
#                                                 text  target
# 1  From gort44@excite.com Mon Jun 24 17:54:21 200...       1
# 2  From fork-admin@xent.com Mon Jul 29 11:39:57 2...       1
# 3  From dcm123@btamail.net.cn Mon Jun 24 17:49:23...       1
# 4  From ilug-admin@linux.ie Mon Aug 19 11:02:47 2...       0
# 5  From tobaccodemon@terra.es Sat Sep 7 22:05:58 ...       1

# %% [markdown]
# now we will convert the data into the desired format for performing our operations and also to divide the dataset into the training and the testing data

# %%
x,x_test,y,y_test= ms.train_test_split(np.array(df[['text']]),np.array(df['target']),test_size=0.2,random_state=50)
print(x,y)
# Out:
# [['From ilug-admin@linux.ie Tue Aug 6 14:42:14 2002 Return-Path: <ilug-admin@linux.ie> Delivered-To: yyyy@localhost.netnoteinc.com Received: from localhost (localhost [127.0.0.1]) by phobos.labs.netnoteinc.com (Postfix) with ESMTP id ACA5D44138 for <jm@localhost>; Tue, 6 Aug 2002 09:41:10 -0400 (EDT) Received: from phobos [127.0.0.1] by localhost with IMAP (fetchmail-5.9.0) for jm@localhost (single-drop); Tue, 06 Aug 2002 14:41:10 +0100 (IST) Received: from lugh.tuatha.org (root@lugh.tuatha.org [194.125.145.45]) by dogma.slashnull.org (8.11.6/8.11.6) with ESMTP id g76DgOk32640 for <jm-ilug@jmason.org>; Tue, 6 Aug 2002 14:42:24 +0100 Received: from lugh (root@localhost [127.0.0.1]) by lugh.tuatha.org (8.9.3/8.9.3) with ESMTP id OAA00834; Tue, 6 Aug 2002 14:39:14 +0100 X-Authentication-Warning: lugh.tuatha.org: Host root@localhost [127.0.0.1] claimed to be lugh Received: from pheriche.sun.com (pheriche.sun.com [192.18.98.34]) by lugh.tuatha.org (8.9.3/8.9.3) with ESMTP id OAA00799 for 
# ...

# %% [markdown]
# now we will do our preprocessing on the data i.e. we will convert the text into the tokens and then we will convert the tokens into the vectors, and whatever all that means

# %%
translator= str.maketrans('','',punctuation[:11]+punctuation[12]+punctuation[14:])
x=[str(i).translate(translator) for i in x]
x_test=[str(i).translate(translator) for i in x_test]
print(x)
# Out:
# ['Thanks Paul,nThat is the way I am doing right now, but I would like to NOT use the mouse nfor such things. Any other cluenn nnSaludos,nUlisesnn Speaking words of wisdom ...nnn In a message dated Thu, 22 Aug 2002 130357 CDTn Ulises Ponce saidn n Thanks Tony, but I think doing it using component files will get a .signature n by default, but I have many diferent signatures and I want to insert one of n that signatures using a keyboard command. So for a message I will insert a n signature, but for another message I will insert a different signature.n n Is it possible I am using sedit for my messages.n n Ahm, if you dont object to using a mouse for such things, exmh has n the ability to insert different sigs on demand.  Create a bunch of n different sig files, all beginning with .signature, and at start up, n exmh will load them all.  In the Sedit window, youll see a Sign...n menu item which will allow you to select between each of the listed n .signature files for that email.  You can 
# ...
